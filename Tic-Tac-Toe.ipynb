# %%
#Welcome message
print("Welcome to Tic-Tac-Toe!")

#Creating the grid
square_1 = "   "
square_2 = "   "
square_3 = "   "
square_4 = "   "
square_5 = "   "
square_6 = "   "
square_7 = "   "
square_8 = "   "
square_9 = "   "
print("-------------")
print("| 1 | 2 | 3 |")
print("-------------")
print("| 4 | 5 | 6 |")
print("-------------")
print("| 7 | 8 | 9 |")
print("-------------")

#game
current_round = 1
while True: 
  if current_round % 2 == 0:
    symbol = "O"
    print("Current player: O")
  else:
    symbol = "X"
    print("Current player: X")
  #symbol = input("Choose: O or X")
  square = input("Choose your square: 1-9\n")

  if square == "1":
    square_1 = " " + symbol + " "
  elif square == "2":
    square_2 = " " + symbol + " " 
  elif square == "3":
    square_3 = " " + symbol + " "
  elif square == "4":
    square_4 = " " + symbol + " "
  elif square == "5":
    square_5 = " " + symbol + " "
  elif square == "6":
    square_6 = " " + symbol + " " 
  elif square == "7":
    square_7 = " " + symbol + " "
  elif square == "8":
    square_8 = " " + symbol + " "
  elif square == "9":
    square_9 = " " + symbol + " " 
  print("-------------")
  print("|" + square_1 + "|" + square_2 + "|" + square_3 + "|")
  print("-------------")
  print("|" + square_4 + "|" + square_5 + "|" + square_6 + "|")
  print("-------------")
  print("|" + square_7 + "|" + square_8 + "|" + square_9 + "|")
  print("-------------")
  current_round += 1

#Winning the game
  if square_1 == square_2 == square_3 != "   ":
    print(symbol + " won!")
    break
  elif square_4 == square_5 == square_6 != "   ":
    print(symbol + " won!")
    break
  elif square_7 == square_8 == square_9 != "   ":
    print(symbol + " won!")
    break
  elif square_1 == square_5 == square_9 != "   ":
    print(symbol + " won!")
    break
  elif square_3 == square_5 == square_7 != "   ":
    print(symbol + " won!")
    break
  elif square_1 == square_4 == square_7 != "   ":
    print(symbol + " won!")
    break
  elif square_2 == square_5 == square_8 != "   ":
    print(symbol + " won!")
    break
  elif square_3 == square_6 == square_9 != "   ":
    print(symbol + " won!")
    break
# Out:
# Welcome to Tic-Tac-Toe!
# -------------
# | 1 | 2 | 3 |
# -------------
# | 4 | 5 | 6 |
# -------------
# | 7 | 8 | 9 |
# -------------
# Current player: X
# Choose your square: 1-9
# 3
# -------------
# |   |   | X |
# -------------
# |   |   |   |
# -------------
# |   |   |   |
# -------------
# Current player: O
# Choose your square: 1-9
# 4
# -------------
# |   |   | X |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Current player: X
# Choose your square: 1-9
# 3
# -------------
# |   |   | X |
# -------------
# | O |   |   |
# -------------
# |   |   |   |
# -------------
# Current player: O
# Choose your square: 1-9
# 6
# -------------
# |   |   | X |
# -------------
# | O |   | O |
# -------------
# |   |   |   |
# -------------
# Current player: X
# Choose your square: 1-9
# 8
# -------------
# |   |   | X |
# -------------
# | O |   | O |
# -------------
# |   | X |   |
# -------------
# Current player: O
# Choose your square: 1-9
# 9
# -------------
# |   |   | X |
# -------------
# | O |   | O |
# -------------
# |   | X | O |
# -------------
# Current player: X
# Choose your square: 1-9
# 2
# -------------
# |   | X | X |
# -------------
# | O |   | O |
# -------------
# |   | X | O |
# -------------
# Current player: O
# Choose your square: 1-9
# 5
# -------------
# |   | X | X |
# -------------
# | O | O | O |
# -------------
# |   | X | O |
# -------------
# O won!
